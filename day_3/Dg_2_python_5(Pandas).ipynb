# %% [markdown]
# **Pandas - Python library for data science & analysis**

# %%
import pandas as pd

employees = {"id" : [1,2,3,4,5,6] ,
             "Names":["Ravi","Rahul","Ajay","Anuj","Abhay","Pavan"],
             "Age":[23,22,24,26,24,27],
             "Emails" : ["ravi@gmail.com","rahul@gmail.com","ajay@gmail.com","anuj@gmail.com","abhay@gmail.com","pavan@gmail.com"]}

print(employees)
# Out:
# {'id': [1, 2, 3, 4, 5, 6], 'Names': ['Ravi', 'Rahul', 'Ajay', 'Anuj', 'Abhay', 'Pavan'], 'Age': [23, 22, 24, 26, 24, 27], 'Emails': ['ravi@gmail.com', 'rahul@gmail.com', 'ajay@gmail.com', 'anuj@gmail.com', 'abhay@gmail.com', 'pavan@gmail.com']}

# %%
df = pd.DataFrame(employees)  #DataFrame()
df
# Out:
#    id  Names  Age           Emails
# 0   1   Ravi   23   ravi@gmail.com
# 1   2  Rahul   22  rahul@gmail.com
# 2   3   Ajay   24   ajay@gmail.com
# 3   4   Anuj   26   anuj@gmail.com
# 4   5  Abhay   24  abhay@gmail.com
# 5   6  Pavan   27  pavan@gmail.com

# %%
import numpy as np

n1 = np.random.randint(0,20,size=(5,4))
n1
# Out:
# array([[14, 19, 10, 11],
#        [ 6,  8, 14, 14],
#        [13,  8, 12, 11],
#        [ 1,  2, 18,  9],
#        [ 3, 17,  5,  2]])

# %%
d1 = pd.DataFrame(n1)

d1.columns = ['A','B','C','D']
d1.index = [1,2,3,4,5]

d1
# Out:
#     A   B   C   D
# 1  14  19  10  11
# 2   6   8  14  14
# 3  13   8  12  11
# 4   1   2  18   9
# 5   3  17   5   2

# %% [markdown]
# **comma seperated values**

# %%
df1 = pd.read_csv('/content/Call Center Data.csv')
df1.head()
# Out:
#    Experience in months  Call Attended in a day
# 0                    12                      30
# 1                    24                      35
# 2                    60                      45
# 3                    72                      50
# 4                    84                      50

# %%
df1.dtypes
# Out:
# Experience in months      int64
# Call Attended in a day    int64
# dtype: object

# %%
print(df1['Call Attended in a day'].mean())
print(df1['Call Attended in a day'].sum())
print(df1['Call Attended in a day'].max())
print(df1['Call Attended in a day'].min())
# Out:
# 65.57657657657657
# 7279
# 101
# 26

# %%
df1.columns
# Out:
# Index(['Experience in months', 'Call Attended in a day'], dtype='object')

# %%
df1.sort_values('Experience in months')
# Out:
#     Experience in months  Call Attended in a day
# 0                     12                      30
# 9                     14                      81
# 20                    14                      38
# 86                    15                      75
# 19                    15                      35
# ..                   ...                     ...
# 53                   105                      35
# 59                   110                      84
# 45                   110                      84
# 43                   120                      39
# 42                   120                      37
#
# [111 rows x 2 columns]

# %%
df1.sort_values('Experience in months', ascending=False)
# Out:
#     Experience in months  Call Attended in a day
# 43                   120                      39
# 42                   120                      37
# 45                   110                      84
# 59                   110                      84
# 53                   105                      35
# ..                   ...                     ...
# 19                    15                      35
# 86                    15                      75
# 20                    14                      38
# 9                     14                      81
# 0                     12                      30
#
# [111 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df1['Experience in months'] , df1['Call Attended in a day'])

plt.show()

# %%
df1.head()
# Out:
#    Experience in months  Call Attended in a day
# 0                    12                      30
# 1                    24                      35
# 2                    60                      45
# 3                    72                      50
# 4                    84                      50

# %% [markdown]
# * fetch a data row => .loc

# %%
#.loc

df1.loc[4]
# Out:
# Experience in months      84
# Call Attended in a day    50
# Name: 4, dtype: int64

# %%
df1.loc[4:10]
# Out:
#     Experience in months  Call Attended in a day
# 4                     84                      50
# 5                     24                      37
# 6                     36                      40
# 7                     96                      45
# 8                     36                      42
# 9                     14                      81
# 10                    22                      82

# %%
df1.loc[4:10 , 'Experience in months']
# Out:
# 4     84
# 5     24
# 6     36
# 7     96
# 8     36
# 9     14
# 10    22
# Name: Experience in months, dtype: int64
